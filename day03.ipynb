# %% [markdown]
# # Instructions
# Below is a dataframe containing worldwide covid data
#
# You must complete 1 question for your warm up :)
#
#
# Happy Learning!!!!

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
# this will randomly sample our dataframe and conver the sample to a dictionary
random_rows = df.sample(10).to_dict()

# %% [markdown]
# ## find the total number of new_cases in random_rows

# %%
# code goes here
